# %%
import pstats
p = pstats.Stats('profile.txt')
p.sort_stats('cumulative').print_stats(10)
# Out:
# Thu Jan  8 13:26:18 2026    profile.txt
#
#          38637247 function calls (38503675 primitive calls) in 35.916 seconds
#
#    Ordered by: cumulative time
#    List reduced from 9538 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    4119/1    0.121    0.000   35.922   35.922 {built-in method builtins.exec}
#         1    0.055    0.055   35.922   35.922 vae_mnist_working.py:1(<module>)
#      3006    0.011    0.000   14.836    0.005 /Users/kenzomaetanimachholm/Desktop/DTU/Jan2026/dtu_mlops/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:727(__next__)
#      3006    0.045    0.000   14.739    0.005 /Users/kenzomaetanimachholm/Desktop/DTU/Jan2026/dtu_mlops/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:786(_next_data)
# ...
